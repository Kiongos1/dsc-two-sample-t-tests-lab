# %% [markdown]
# # Two Sample T-Test - Lab
#
# ## Introduction
#
# The two sample t-test is used to determine if two population means are equal. A common application is to test if a new process or treatment is superior to a current process or treatment.
#
# ## Objectives
#
# You will be able to:
#
# * Perform a two-sample t-test and make conclusions about an experiment based on the results
# * Visually represent the t-test and p-value using the t-distribution
#
# ## Example:
#
# Consider the following experimental settings for clinical trials of a new blood pressure medicine.
#
# In the context of controlled experiments, you will often see talk about the "control" group and the "experimental" or "treatment" group. In a drug test example, the control group is the group given the placebo and the treatment group is given the actual drug. Researchers are interested in the average difference in blood pressure levels between the treatment and control groups.
#
# >The 50 subjects in the control group have an average systolic blood pressure of 121.38 who have been given a placebo drug.
#
# >The 50 subjects in the experimental / treatment group have an average systolic blood pressure of 111.56 after treatment with the drug being tested.
#
# The apparent difference between experimental and control groups is -9.82 points. But with 50 subjects in each group, how confident can a researcher be that this measured difference is real? You can perform a two sample t-test to evaluate this.
#
# First, you will calculate a t-statistic for a 2-sample t-test, then calculate a p-value.
#
# The experimental and control observations are given below as NumPy arrays.
#
# First, let's make sure to import necessary libraries:

# %%
import numpy as np
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style('whitegrid')

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

# %%
# Use this sample data to conduct experimentation

control = np.array([166, 165, 120,  94, 104, 166,  98,  85,  97,  87, 114, 100, 152,
                    87, 152, 102,  82,  80,  84, 109,  98, 154, 135, 164, 137, 128,
                    122, 146,  86, 146,  85, 101, 109, 105, 163, 136, 142, 144, 140,
                    128, 126, 119, 121, 126, 169,  87,  97, 167,  89, 155])

experimental = np.array([ 83, 100, 123,  75, 130,  77,  78,  87, 116, 116, 141,  93, 107,
                         101, 142, 152, 130, 123, 122, 154, 119, 149, 106, 107, 108, 151,
                         97,  95, 104, 141,  80, 110, 136, 134, 142, 135, 111,  83,  86,
                         116,  86, 117,  87, 143, 104, 107,  86,  88, 124,  76])

# %% [markdown]
# It is always a good idea to create a plot of the probability distributions for samples to visually inspect the differences present between mean and standard deviation. Plot both samples' distributions and inspect the overlap using `seaborn` to get an idea of how different the samples might be from one another.

# %%
# Create a plot showing overlapping of distribution means and sds for inspection
def plot_distributions(control, experimental):
    sns.kdeplot(control, label='Control', color='blue', fill=True)
    sns.kdeplot(experimental, label='Experimental', color='orange', fill=True)
    plt.title('Distribution of Control and Experimental Groups')
    plt.xlabel('Values')
    plt.ylabel('Density')
    plt.legend()
    plt.show()  
# Conduct a t-test to compare the means of the two groups
def conduct_t_test(control, experimental):
    t_stat, p_value = stats.ttest_ind(control, experimental, equal_var=False)
    print(f"T-statistic: {t_stat:.4f}, P-value: {p_value:.4f}")
# Main function to run the analysis
def main():
    print("Plotting distributions...")
    plot_distributions(control, experimental)
    print("Conducting t-test...")
    conduct_t_test(control, experimental)
if __name__ == "__main__":
    main()
# This code performs a t-test on two sample datasets and visualizes their distributions.
# It uses seaborn for plotting and scipy for statistical testing.
# The t-test checks if there is a significant difference between the means of the control and experimental groups.
# The plot shows the density distributions of both groups, allowing for visual inspection of their overlap.
# The t-test results include the t-statistic and p-value, which indicate the significance of the difference.
# The code is structured to be run as a script, with a main function that orchestrates the plotting and testing.
# The use of numpy arrays allows for efficient numerical operations, and the seaborn library provides a high-level interface for drawing attractive statistical graphics.
# The code is designed to be clear and modular, making it easy to adapt for different datasets or analyses.
# The analysis can be extended by adding more statistical tests or visualizations as needed.
# The code is suitable for educational purposes, demonstrating basic statistical analysis and visualization techniques in Python.
# The script can be run in a Jupyter notebook or any Python environment that supports the required libraries.
# The code is a good starting point for anyone interested in learning about hypothesis testing and data visualization in Python.
# The analysis can be useful in various fields such as psychology, biology, and social sciences where comparing groups is common.
# The t-test is a fundamental statistical method that helps in making inferences about population means based on sample data.
# The code is efficient and leverages the power of Python's scientific libraries to perform statistical analysis with ease.
# The results of the t-test can guide decision-making in experimental designs and research studies.
# The visualization helps in understanding the data distribution and the potential impact of the experimental treatment.
# The code can be modified to include additional statistical tests or visualizations as needed.
# The analysis can be extended to include confidence intervals or effect sizes for a more comprehensive understanding of the results.
# The script is a practical example of how to apply statistical methods in Python for data analysis.
# The use of inline plotting makes it convenient for exploratory data analysis in Jupyter notebooks.
# Out:
# Plotting distributions...
# Conducting t-test...
# T-statistic: 1.8915, P-value: 0.0616

# %% [markdown]
# There are some slight differences between the mean and standard deviation of the control and experimental groups. This is a good sign to further our experimentation and to calculate whether the difference is significant, or not. As a reminder the five steps to performing a hypothesis test are:
#
# 1) Set up null and alternative hypotheses
# 2) Choose a significance level
# 3) Calculate the test statistic
# 4) Determine the critical or p-value (find the rejection region)
# 5) Compare t-value with critical t-value to reject or fail to reject the null hypothesis
#
# ## The Null Hypothesis
#
# In thus drug efficacy experiment example, you can define the null hypothesis to be that there is no difference between a subject taking a placebo and the treatment drug.
#
# >**$H_{0}$: The mean difference between treatment and control groups is zero. i.e. $\mu_{0} = \mu_{1}$**
#
# ## The Alternate Hypothesis
#
# In this example, the alternative hypothesis is that there is in fact a mean difference in blood pressure between the treatment and control groups.
#
# >**$H_{1}$ (2-tailed): The parameter of interest, our mean difference between treatment and control, is different than zero.**
#
# >**$H_{1}$ (1-tailed, >): The parameter of interest, our mean difference between treatment and control, is greater than zero.**
#
# >**$H_{1}$ (1-tailed, <): The parameter of interest, our mean difference between treatment and control, is less than zero.**
#
# NOTE: The null hypothesis and alternative hypothesis are concerned with the true values, or in other words the parameter of the overall population. Through the process of experimentation/hypothesis testing and statistical analysis of the results, we will make an inference about this population parameter.
#
# Now, calculate the mean difference between both groups.

# %%
# calculate the mean difference between both groups
def calculate_mean_difference(control, experimental):
    mean_control = np.mean(control)
    mean_experimental = np.mean(experimental)
    mean_difference = mean_control - mean_experimental
    print(f"Mean Control: {mean_control:.2f}, Mean Experimental: {mean_experimental:.2f}")
    print(f"Mean Difference: {mean_difference:.2f}")
    return mean_difference
# Main function to run the analysis with mean difference calculation
def main_with_mean_difference():
    print("Plotting distributions...")
    plot_distributions(control, experimental)
    print("Conducting t-test...")
    conduct_t_test(control, experimental)
    print("Calculating mean difference...")
    calculate_mean_difference(control, experimental)
if __name__ == "__main__":
    main_with_mean_difference()
# This code extends the previous analysis by adding a function to calculate and print the mean difference
# between the control and experimental groups. It provides a more comprehensive understanding of the data.
# The mean difference is a useful statistic that summarizes the effect size of the experimental treatment.
# The code maintains the structure of the previous script, allowing for easy integration of the new functionality.
# Out:
# Plotting distributions...
# Conducting t-test...
# T-statistic: 1.8915, P-value: 0.0616
# Calculating mean difference...
# Mean Control: 121.38, Mean Experimental: 111.56
# Mean Difference: 9.82

# %% [markdown]
# What is the probability that you would observe this data GIVEN a specified mean difference in blood pressure?
#
# You obviously don't know the true mean difference in blood pressure resulting from administration of the drug. The whole point of conducting the experiment is to evaluate the drug. Instead, you must assume that the true mean difference is zero: the null hypothesis $H_{0}$ is assumed to be true:
#
# ## Calculating the t-statistic
# When comparing the difference between groups, we can calculate the two-sample t-statistic like so:
#
# $$\large t = \frac{\bar{x}_{1} - \bar{x}_{2}}{\sqrt{s^{2}_{p} (\frac{1}{n_{1}} + \frac{1}{n_{2}}) }    }  $$
#
# Where $s^{2}_{p}$ is the pooled sample variance, calculated as:
#
# $$\large s^{2}_{p}  = \frac{(n_{1} -1)s^{2}_{1} +  (n_{2} -1)s^{2}_{2}}{n_{1} + n_{2} - 2}  $$
#
# Where $s^{2}_{1}$ and $s^{2}_{2}$ are the variances for each sample given by the formula
# $$ \large s^{2} = \frac{\sum_{i=1}^{n}(x_{i} - \bar{x})^{2}}{n-1} $$
#
#
# ## Calculating pooled sample variance
# The $s^2_{p}$ denotes the sample variance. In this version of the t-test, you are assuming equal variances in our experimental and control groups in the overall population. There is another way to calculate the t-test where equal variance is not assumed, but in this case, it is a reasonable assumption.
#
# This approach combines the variance of the two group's variance measurements into a single, pooled metric.
#
# Now, create some functions to calculate the t-statistic. The first function to create is one that calculates the variance for a single sample.

# %%
def sample_variance(sample):
    """Calculate the sample variance of a given sample."""
    n = len(sample)
    if n < 2:
        print("Sample size must be at least 2 to calculate variance.")
        return None
    mean = np.mean(sample)
    variance = np.sum((sample - mean) ** 2) / (n - 1)
    return variance if variance > 0 else None
    print("Sample variance must be greater than zero.")
    # This function calculates the sample variance of a given sample.
    # It checks if the sample size is at least 2 and returns the variance if it is greater than zero.
    # If the sample size is less than 2 or the variance is not positive, it returns None.
    
    
    return None

# %% [markdown]
# Using `sample_variance`, you can now write another function `pooled_variance` to calculate $s_{p}^{2}$

# %%
def pooled_variance(sample1, sample2):
    """Calculate the pooled variance of two samples."""
    var1 = sample_variance(sample1)
    var2 = sample_variance(sample2)
    if var1 is not None and var2 is not None:
        n1 = len(sample1)
        n2 = len(sample2)
        pooled_var = ((n1 - 1) * var1 + (n2 - 1) * var2) / (n1 + n2 - 2)
        return pooled_var if pooled_var > 0 else None
    print("Pooled variance must be greater than zero.")
    # This function calculates the pooled variance of two samples.
    # It first calculates the sample variances of both samples and checks if they are valid.
    # If both variances are valid, it computes the pooled variance and returns it if it is greater than zero.
    # If not, it returns None.
    
    return None

# %% [markdown]
# Now that you have $s_{p}^{2}$, create a function `twosample_tstatistic` to calculate the two sample t-statistic using the formula given earlier.

# %%
def twosample_tstatistic(expr, ctrl):
    """Calculate the two-sample t-statistic."""
    n1 = len(expr)
    n2 = len(ctrl)
    if n1 < 2 or n2 < 2:
        print("Both samples must have at least 2 observations to calculate t-statistic.")
        return None
    pooled_var = pooled_variance(expr, ctrl)
    if pooled_var is not None:
        mean_expr = np.mean(expr)
        mean_ctrl = np.mean(ctrl)
        t_stat = (mean_expr - mean_ctrl) / np.sqrt(pooled_var * (1/n1 + 1/n2))
        return t_stat if not np.isnan(t_stat) else None
    print("Pooled variance must be greater than zero to calculate t-statistic.")
    # This function calculates the two-sample t-statistic using the means and pooled variance of two samples.
    # It checks if both samples have at least 2 observations and if the pooled variance is valid.
    # If valid, it computes the t-statistic and returns it; otherwise, it returns None.

    return None

t_stat = None
# -1.8915462966190268

# %% [markdown]
# Using the data from the samples, you can now determine the critical values with the t-statistic and calculate the area under the curve to determine the p-value.
#
# Write a function `visualize_t` that uses matplotlib to display a standard t-distribution with vertical lines identifying each critical value that signifies the rejection region.

# %%
# Visualize t and p_value

def visualize_t(t_stat, n_control, n_experimental):


    # initialize a matplotlib "figure"
    plt.figure(figsize=(10, 6))
    # generate points on the x axis between -4 and 4:
    x = np.linspace(-4, 4, 1000)
    # use stats.t.pdf to get values on the probability density function for the t-distribution
    df = n_control + n_experimental - 2  # degrees of freedom
    y = stats.t.pdf(x, df)
    plt.plot(x, y, label='t-distribution', color='blue')
    plt.title('T-Distribution with Critical T Boundaries')
    plt.xlabel('t-value')
    plt.ylabel('Probability Density')
    plt.axvline(t_stat, color='red', linestyle='--', label=f'T-statistic: {t_stat:.2f}')
    plt.axhline(0, color='black', linewidth=0.5, linestyle='--')
    plt.legend()
    plt.grid(True)
    plt.xlim(-4, 4)
    plt.ylim(0, 0.5)
    # Draw two sided boundary for critical-t
    critical_t = stats.t.ppf(0.975, df)  # two-tailed test at alpha = 0.05
    plt.axvline(critical_t, color='green', linestyle='--', label=f'Critical t: {critical_t:.2f}')
    plt.axvline(-critical_t, color='green', linestyle='--')
    plt.legend()
    plt.show()
    # This function visualizes the t-statistic and the t-distribution.      
    # It generates a plot showing the t-distribution, the t-statistic, and the critical t boundaries.
    # It uses matplotlib to create the plot and seaborn for styling.
    # It calculates the degrees of freedom based on the sample sizes and uses the t-distribution to plot the probability density function.
    # The critical t values are calculated for a two-tailed test at a significance level of 0.05.
    # The plot includes labels, a legend, and grid lines for better readability.
    # This function visualizes the t-statistic and the t-distribution.

    # generate points on the x axis between -4 and 4:
 
    # use stats.t.pdf to get values on the probability density function for the t-distribution
    
    # Draw two sided boundary for critical-t



n_control = len(control)
n_experimental = len(experimental)
t_stat = twosample_tstatistic(experimental, control)
visualize_t(t_stat, n_control, n_experimental)
# This code calculates the t-statistic for two samples and visualizes it along with the t-distribution.
# - This code calculates the t-statistic for two samples and visualizes it along with the t-distribution.
# - It uses the `twosample_tstatistic` function to compute the t-statistic based on the experimental and control samples.
# - The `visualize_t` function generates a plot showing the t-distribution, the t-statistic, and the critical t boundaries.
# - The plot includes labels, a legend, and grid lines for better readability.
# - The critical t values are calculated for a two-tailed test at a significance level of 0.05.
# - The code uses matplotlib for plotting and seaborn for styling.
# - The visualization helps in understanding the significance of the t-statistic in relation to the t-distribution.
# - The code is structured to be modular, allowing for easy integration of additional functionality or modifications.
# - The analysis can be extended to include confidence intervals or effect sizes for a more comprehensive understanding of the results.

# %% [markdown]
# Now that you have defined your boundaries for significance, you can simply calculate the p-value by calculating the total area under curve using `stats.t.cdf()`.
#
# Given a t-value and the degrees of freedom, you can use the "survival function", `sf` of `scipy.stats.t` (aka the complementary CDF) to compute the one-sided p-value. For the two-sided p-value, just double the one-sided p-value.

# %%
## Calculate p_value
# Lower tail comulative density function returns area under the lower tail curve
lower_tail = stats.t.cdf(-1.89, (50+50-2), 0, 1)
# Upper tail comulative density function returns area under upper tail curve
upper_tail = 1. - stats.t.cdf(1.89, (50+50-2), 0, 1)

p_value = lower_tail+upper_tail
print(p_value)
# Out:
# 0.061713104303855494

# %% [markdown]
# To verify these results, you can use SciPy's functions to calculate the p_value in a one liner.

# %%
## your code here
'''
Calculates the t-test for the means of *two independent* samples of scores.

This is a two-sided test for the null hypothesis that 2 independent samples
have identical average (expected) values. This test assumes that the
populations have identical variances by default.
'''

stats.ttest_ind(experimental, control)
# Out:
# Ttest_indResult(statistic=-1.8915462966190273, pvalue=0.0615042406725304)

# %% [markdown]
# ## Summary
# In this lesson, you ran hypothesis testing using frequentists methods with t-values and p-values. You saw how a two sample t-test can be applied to contexts where the population and sample mean are known and you have a limited amount of sample data. You looked at all the stages required for such hypothesis testing with a description of the steps and also how to perform these functions in python. You also used built-in SciPy functions to calculate test statistics and p-value as a way to verify the manual calculations performed.
